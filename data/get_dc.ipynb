# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/cristiancruz/Downloads/lds-scriptures-2020.12.08/csv/lds-scriptures.csv")

# %%
df.head()
# Out:
#    volume_id  book_id  chapter_id  verse_id   volume_title book_title  \
# 0          1        1           1         1  Old Testament    Genesis
# 1          1        1           1         2  Old Testament    Genesis
# 2          1        1           1         3  Old Testament    Genesis
# 3          1        1           1         4  Old Testament    Genesis
# 4          1        1           1         5  Old Testament    Genesis
#
#    volume_long_title                         book_long_title volume_subtitle  \
# 0  The Old Testament  The First Book of Moses called Genesis             NaN
# 1  The Old Testament  The First Book of Moses called Genesis             NaN
# 2  The Old Testament  The First Book of Moses called Genesis             NaN
# 3  The Old Testament  The First Book of Moses called Genesis             NaN
# 4  The Old Testament  The First Book of Moses called Genesis             NaN
#
#   book_subtitle volume_short_title book_short_title volume_lds_url  \
# ...

# %%
dc_df = df[df['volume_title'] == 'Doctrine and Covenants']
dc_df.head()
# Out:
#        volume_id  book_id  chapter_id  verse_id            volume_title  \
# 37706          4       82        1429     37707  Doctrine and Covenants
# 37707          4       82        1429     37708  Doctrine and Covenants
# 37708          4       82        1429     37709  Doctrine and Covenants
# 37709          4       82        1429     37710  Doctrine and Covenants
# 37710          4       82        1429     37711  Doctrine and Covenants
#
#                    book_title           volume_long_title  \
# 37706  Doctrine and Covenants  The Doctrine and Covenants
# 37707  Doctrine and Covenants  The Doctrine and Covenants
# 37708  Doctrine and Covenants  The Doctrine and Covenants
# 37709  Doctrine and Covenants  The Doctrine and Covenants
# 37710  Doctrine and Covenants  The Doctrine and Covenants
#
#                   book_long_title volume_subtitle  \
# 37706  The Doctrine and Covenants             NaN
# 37707  The Doctrine and Covenants             NaN
# ...

# %%
dc_df.to_csv('dc.csv')
